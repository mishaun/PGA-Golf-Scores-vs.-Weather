# %% [markdown]
# # Read Libs

# %%
import pandas as pd
import datetime as dt
import pdb
import numpy as np
import configparser
import os
import regex as re

# display and output settings
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

from IPython.display import display, HTML

display(HTML('''
<style>
    .container { width:85% !important; }
</style>
'''))

pd.set_option('display.min_rows', 20)
# Out:
# <style>
#     .container { width:85% !important; }
# </style>

# %% [markdown]
# # Transform Data

# %% [markdown]
# ## Clean Scores Data

# %% [markdown]
# ### Reading In Data and Selecting Columns

# %%
scores_df_1 = pd.read_csv('../data/raw_data/tournament_scores/batch_1/2024-09-22 15h28m07s/tournament_scores.csv')
scores_df_2 = pd.read_csv('../data/raw_data/tournament_scores/batch_2/2024-09-22 14h03m51s/tournament_scores.csv')
scores_df = pd.concat([scores_df_1, scores_df_2])
# Out:
# /Users/Mishaun_Bhakta/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (11,13) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
cols_scores = [
    "event_id",
    "POS",
    "PLAYER",
    "SCORE",
    "R1",
    "R2",
    "R3",
    "R4",
    "TOT",
    "EARNINGS",
    "FEDEX PTS"
]

# %%
scores_df = scores_df[cols_scores]

# %% [markdown]
# ### identifying events that did not have complete score information

# %%
# creatiing a dataframe with the number of players per event
scores_df_agg = scores_df.groupby('event_id').count()

# %% [markdown]
# * will remove events that had less than 5 players in the scores table

# %%
# getting event ids that had more than 5 player threshold 
players_threshold_minimum = 5
keep_eventids = list(scores_df_agg[scores_df_agg['POS']>players_threshold_minimum]\
                     .reset_index()['event_id'])

# %%
scores_df = scores_df[scores_df['event_id'].isin(keep_eventids)]

# %% [markdown]
# ## Clean Tournament Details

# %%
details_df_1 = pd.read_csv('../data/raw_data/tournament_info/batch_1/2024-09-15 15h13m10s/tournament_info.csv')
details_df_2 = pd.read_csv('../data/raw_data/tournament_info/batch_2/2024-09-22 16h43m40s/tournament_info.csv')


#filtering batch 1 details 
details_df_1 = details_df_1[details_df_1['event_id'] <= 3756]

#filtering batch 2 details to be event id's greater than batch 1's last id
details_df_2 = details_df_2[details_df_2['event_id'] > 3756]

details_df = pd.concat([details_df_1, details_df_2])
# Out:
# /Users/Mishaun_Bhakta/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (1,2,3,4,5) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
# filtering out null or no detail titles
details_df = details_df[~details_df['tournament_title'].isnull()]
details_df = details_df[details_df['tournament_title'] != "No details found"]

# %% [markdown]
# ### Adding Fields to Details

# %%
# adding city to details 
details_df['city'] = details_df['golf_course'].apply(lambda x: x.split("-")[-1])

# %%
def clean_purse(row_value):
    """
    Cleans the purse value from a given row.

    This function takes a row value, removes any commas, and extracts the first 
    dollar amount found. If no dollar amount is found, it returns NaN.

    Parameters:
    row_value (str): The value from the row which may contain a dollar amount.

    Returns:
    str or float: The cleaned dollar amount as a string without the dollar sign, 
                  or NaN if no dollar amount is found.
    """

    row_value_clean = str(row_value).replace(",", "")

    matches = re.findall("\$\d+", row_value_clean)

    if matches:
        return matches[0].replace("$", "") 
    else:
        return np.nan


# details_df['purse'].apply(lambda x: re.findall("\$\d+", str(x).replace(",", "")))
details_df['purse'] = details_df['purse'].apply(clean_purse)

# %%
def clean_course_yards(row_value):

    matches = re.findall("Yards.*", row_value)

    if matches:
        return int(matches[0].replace("Yards", "") )
    else:
        return np.nan
    

def clean_course_par(row_value):

    matches = re.findall("Par\d{2}", row_value)

    if matches:
        return int(matches[0].replace("Par", "") )
    else:
        return np.nan

# %%
# applying functions to create par and yards fields
details_df['Yards'] = details_df['course_details'].apply(clean_course_yards)
details_df['Par'] = details_df['course_details'].apply(clean_course_par)

# %% [markdown]
# ### need to create dates start and finish for event date

# %%
details_df
def extract_start_end_dates(event_date):
    """
    Extracts the start and end dates from the event_date column.

    Parameters:
    event_date (str): The event date string in the format 'Month Day - Day, Year'.

    Returns:
    tuple: A tuple containing the start date and end date as datetime objects.
    """
    try:
        # Split the event_date string
        parts = event_date.split(',')
        year = parts[1].strip()
        days = parts[0].split('-')
        
        # Extract start and end dates
        start_date_str = f"{days[0].strip()} {year}"
        end_date_str = f"{days[1].strip()} {year}"
        
        # Convert to datetime objects
        start_date = dt.datetime.strptime(start_date_str, '%B %d %Y')
        end_date = dt.datetime.strptime(end_date_str, '%B %d %Y')
        
        return start_date, end_date
    except Exception as e:
        print(f"Error processing date: {event_date}, Error: {e}")
        return np.nan, np.nan

details_df[['start_date', 'end_date']] = details_df['event_date'].apply(lambda x: pd.Series(extract_start_end_dates(x)))
# Out:
#        event_id                       tournament_title  \
# 1             1  WGC-Accenture Match Play Championship
# 2             2                 Mercedes Championships
# 3             3          Touchstone Energy Tucson Open
# 4             4                    Sony Open in Hawaii
# 5             5                           Phoenix Open
# 6             6      AT&T Pebble Beach National Pro-Am
# 7             7                     Buick Invitational
# 8             8              Bob Hope Chrysler Classic
# 9             9                            Nissan Open
# 10           10                   Genuity Championship
# ...         ...                                    ...
# 4760  401580357                Rocket Mortgage Classic
# 4761  401580358                     John Deere Classic
# 4762  401580359                  Genesis Scottish Open
# 4763  401580360                               The Open
# 4764  401580361                 Barracuda Championship
# 4765  401580362                                3M Open
# 4766  401580363                   Wyndham Championship
# 4767  401580364            FedEx St. Jude Championship
# 4768  401580365                       BMW Championship
# 4769  401580366                      TOUR Championship
#
#                       event_date  \
# 1            January 4 - 7, 2001
# 2          January 11 - 14, 2001
# 3          January 11 - 14, 2001
# 4          January 18 - 21, 2001
# 5          January 25 - 28, 2001
# 6           February 1 - 4, 2001
# 7          February 8 - 11, 2001
# 8         February 14 - 18, 2001
# 9         February 22 - 25, 2001
# 10             March 1 - 4, 2001
# ...                          ...
# 4760          June 27 - 30, 2024
# 4761            July 4 - 7, 2024
# 4762          July 11 - 14, 2024
# 4763          July 18 - 21, 2024
# 4764          July 18 - 21, 2024
# 4765          July 25 - 28, 2024
# 4766         August 8 - 12, 2024
# 4767        August 15 - 18, 2024
# 4768        August 22 - 25, 2024
# 4769  Aug 29 - September 1, 2024
#
#                                             golf_course    course_details  \
# 1                                      No details found  No details found
# 2      Kapalua Resort (Plantation Course) - Kapalua, HI    Par73Yards7411
# 3     Omni Tucson National Golf Resort and Spa - Tuc...    Par72Yards7213
# 4                   Waialae Country Club - Honolulu, HI    Par70Yards7044
# 5      TPC Scottsdale (Stadium Course) - Scottsdale, AZ  No details found
# 6                                      No details found    Par72Yards6822
# 7                                      No details found  No details found
# 8                                      No details found    Par71Yards6997
# 9          Riviera Country Club - Pacific Palisades, CA  No details found
# 10         Trump National Doral Golf Course - Doral, FL  No details found
# ...                                                 ...               ...
# 4760                    Detroit Golf Club - Detroit, MI    Par72Yards7370
# 4761                         TPC Deere Run - Silvis, IL    Par71Yards7289
# 4762     The Renaissance Club - North Berwick, Scotland    Par70Yards7237
# 4763          Royal Troon Golf Course - Troon, Scotland    Par71Yards7385
# 4764  Tahoe Mountain Club (Old Greenwood) - Truckee, CA    Par71Yards7480
# 4765                       TPC Twin Cities - Blaine, MN    Par71Yards7431
# 4766           Sedgefield Country Club - Greensboro, NC    Par70Yards7131
# 4767                        TPC Southwind - Memphis, TN    Par70Yards7243
# 4768           Castle Pines Golf Club - Castle Rock, CO    Par72Yards8130
# 4769                  East Lake Golf Club - Atlanta, GA    Par71Yards7490
#
#          purse                      city   Yards   Par
# 1      5000000          No details found     NaN   NaN
# 2      3500000               Kapalua, HI  7411.0  73.0
# 3      3000000                Tucson, AZ  7213.0  72.0
# 4      4000000              Honolulu, HI  7044.0  70.0
# 5      4000000            Scottsdale, AZ     NaN   NaN
# 6      4000000          No details found  6822.0  72.0
# 7      3500000          No details found     NaN   NaN
# 8      3500000          No details found  6997.0  71.0
# 9      3400000     Pacific Palisades, CA     NaN   NaN
# 10     4500000                 Doral, FL     NaN   NaN
# ...        ...                       ...     ...   ...
# 4760   9200000               Detroit, MI  7370.0  72.0
# 4761   8000000                Silvis, IL  7289.0  71.0
# 4762   9000000   North Berwick, Scotland  7237.0  70.0
# 4763  17000000           Troon, Scotland  7385.0  71.0
# 4764   4000000               Truckee, CA  7480.0  71.0
# 4765   8100000                Blaine, MN  7431.0  71.0
# 4766   7900000            Greensboro, NC  7131.0  70.0
# 4767  20000000               Memphis, TN  7243.0  70.0
# 4768  20000000           Castle Rock, CO  8130.0  72.0
# 4769       NaN               Atlanta, GA  7490.0  71.0
#
# [2201 rows x 9 columns]
# Error processing date: January 4 - 7, 2001, Error: time data '7 2001' does not match format '%B %d %Y'
# Error processing date: January 11 - 14, 2001, Error: time data '14 2001' does not match format '%B %d %Y'
# Error processing date: January 11 - 14, 2001, Error: time data '14 2001' does not match format '%B %d %Y'
# Error processing date: January 18 - 21, 2001, Error: time data '21 2001' does not match format '%B %d %Y'
# Error processing date: January 25 - 28, 2001, Error: time data '28 2001' does not match format '%B %d %Y'
# Error processing date: February 1 - 4, 2001, Error: time data '4 2001' does not match format '%B %d %Y'
# Error processing date: February 8 - 11, 2001, Error: time data '11 2001' does not match format '%B %d %Y'
# Error processing date: February 14 - 18, 2001, Error: time data '18 2001' does not match format '%B %d %Y'
# Error processing date: February 22 - 25, 2001, Error: time data '25 2001' does not match format '%B %d %Y'
# Error processing date: March 1 - 4, 2001, Error: time data '4 2001' does not match format '%B %d %Y'
# Error processing date: March 8 - 11, 2001, Error: time data '11 2001' does not match format '%B %d %Y'
# Error processing date: March 15 - 18, 2001, Error: time data '18 2001' does not match format '%B %d %Y'
# Error processing date: March 22 - 25, 2001, Error: time data '25 2001' does not match format '%B %d %Y'
# Error processing date: Mar 29 - April 1, 2001, Error: time data 'Mar 29 2001' does not match format '%B %d %Y'
# Error processing date: April 5 - 8, 2001, Error: time data '8 2001' does not match format '%B %d %Y'
# Error processing date: April 12 - 15, 2001, Error: time data '15 2001' does not match format '%B %d %Y'
# Error processing date: April 19 - 22, 2001, Error: time data '22 2001' does not match format '%B %d %Y'
# Error processing date: April 26 - 29, 2001, Error: time data '29 2001' does not match format '%B %d %Y'
# Error processing date: May 3 - 6, 2001, Error: time data '6 2001' does not match format '%B %d %Y'
# Error processing date: May 10 - 13, 2001, Error: time data '13 2001' does not match format '%B %d %Y'
# Error processing date: May 17 - 20, 2001, Error: time data '20 2001' does not match format '%B %d %Y'
# Error processing date: May 24 - 27, 2001, Error: time data '27 2001' does not match format '%B %d %Y'
# Error processing date: June 7 - 10, 2001, Error: time data '10 2001' does not match format '%B %d %Y'
# Error processing date: June 14 - 17, 2001, Error: time data '17 2001' does not match format '%B %d %Y'
# Error processing date: June 21 - 24, 2001, Error: time data '24 2001' does not match format '%B %d %Y'
# Error processing date: Jun 28 - July 1, 2001, Error: time data 'Jun 28 2001' does not match format '%B %d %Y'
# Error processing date: July 5 - 8, 2001, Error: time data '8 2001' does not match format '%B %d %Y'
# Error processing date: July 12 - 15, 2001, Error: time data '15 2001' does not match format '%B %d %Y'
# Error processing date: July 19 - 22, 2001, Error: time data '22 2001' does not match format '%B %d %Y'
# Error processing date: July 19 - 22, 2001, Error: time data '22 2001' does not match format '%B %d %Y'
# Error processing date: July 26 - 29, 2001, Error: time data '29 2001' does not match format '%B %d %Y'
# Error processing date: August 2 - 5, 2001, Error: time data '5 2001' does not match format '%B %d %Y'
# Error processing date: August 9 - 12, 2001, Error: time data '12 2001' does not match format '%B %d %Y'
# Error processing date: August 16 - 19, 2001, Error: time data '19 2001' does not match format '%B %d %Y'
# Error processing date: August 23 - 26, 2001, Error: time data '26 2001' does not match format '%B %d %Y'
# Error processing date: August 23 - 26, 2001, Error: time data '26 2001' does not match format '%B %d %Y'
# Error processing date: Aug 30 - September 2, 2001, Error: time data 'Aug 30 2001' does not match format '%B %d %Y'
# Error processing date: September 6 - 9, 2001, Error: time data '9 2001' does not match format '%B %d %Y'
# Error processing date: September 13 - 16, 2001, Error: time data '16 2001' does not match format '%B %d %Y'
# Error processing date: September 13 - 16, 2001, Error: time data '16 2001' does not match format '%B %d %Y'
# Error processing date: September 20 - 23, 2001, Error: time data '23 2001' does not match format '%B %d %Y'
# Error processing date: September 27 - 30, 2001, Error: time data '30 2001' does not match format '%B %d %Y'
# Error processing date: October 4 - 7, 2001, Error: time data '7 2001' does not match format '%B %d %Y'
# Error processing date: October 10 - 14, 2001, Error: time data '14 2001' does not match format '%B %d %Y'
# Error processing date: October 18 - 21, 2001, Error: time data '21 2001' does not match format '%B %d %Y'
# Error processing date: October 25 - 28, 2001, Error: time data '28 2001' does not match format '%B %d %Y'
# Error processing date: November 1 - 4, 2001, Error: time data '4 2001' does not match format '%B %d %Y'
# Error processing date: November 1 - 4, 2001, Error: time data '4 2001' does not match format '%B %d %Y'
# Error processing date: August 15 - 18, 2002, Error: time data '18 2002' does not match format '%B %d %Y'
# Error processing date: August 22 - 25, 2002, Error: time data '25 2002' does not match format '%B %d %Y'
# Error processing date: August 22 - 25, 2002, Error: time data '25 2002' does not match format '%B %d %Y'
# Error processing date: Aug 29 - September 1, 2002, Error: time data 'Aug 29 2002' does not match format '%B %d %Y'
# Error processing date: September 5 - 8, 2002, Error: time data '8 2002' does not match format '%B %d %Y'
# Error processing date: September 12 - 15, 2002, Error: time data '15 2002' does not match format '%B %d %Y'
# Error processing date: September 19 - 22, 2002, Error: time data '22 2002' does not match format '%B %d %Y'
# Error processing date: September 19 - 22, 2002, Error: time data '22 2002' does not match format '%B %d %Y'
# Error processing date: September 26 - 29, 2002, Error: time data '29 2002' does not match format '%B %d %Y'
# Error processing date: October 3 - 6, 2002, Error: time data '6 2002' does not match format '%B %d %Y'
# Error processing date: October 9 - 13, 2002, Error: time data '13 2002' does not match format '%B %d %Y'
# Error processing date: October 17 - 20, 2002, Error: time data '20 2002' does not match format '%B %d %Y'
# Error processing date: October 24 - 27, 2002, Error: time data '27 2002' does not match format '%B %d %Y'
# Error processing date: Oct 31 - November 3, 2002, Error: time data 'Oct 31 2002' does not match format '%B %d %Y'
# Error processing date: Oct 31 - November 3, 2002, Error: time data 'Oct 31 2002' does not match format '%B %d %Y'
# Error processing date: January 3 - 6, 2002, Error: time data '6 2002' does not match format '%B %d %Y'
# Error processing date: January 10 - 13, 2002, Error: time data '13 2002' does not match format '%B %d %Y'
# Error processing date: January 16 - 20, 2002, Error: time data '20 2002' does not match format '%B %d %Y'
# Error processing date: January 24 - 27, 2002, Error: time data '27 2002' does not match format '%B %d %Y'
# Error processing date: Jan 31 - February 3, 2002, Error: time data 'Jan 31 2002' does not match format '%B %d %Y'
# Error processing date: February 7 - 10, 2002, Error: time data '10 2002' does not match format '%B %d %Y'
# Error processing date: February 14 - 17, 2002, Error: time data '17 2002' does not match format '%B %d %Y'
# Error processing date: February 24, 2002, Error: list index out of range
# Error processing date: February 21 - 24, 2002, Error: time data '24 2002' does not match format '%B %d %Y'
# Error processing date: Feb 28 - March 3, 2002, Error: time data 'Feb 28 2002' does not match format '%B %d %Y'
# Error processing date: March 7 - 10, 2002, Error: time data '10 2002' does not match format '%B %d %Y'
# Error processing date: March 14 - 17, 2002, Error: time data '17 2002' does not match format '%B %d %Y'
# Error processing date: March 21 - 24, 2002, Error: time data '24 2002' does not match format '%B %d %Y'
# Error processing date: March 28 - 31, 2002, Error: time data '31 2002' does not match format '%B %d %Y'
# Error processing date: April 4 - 7, 2002, Error: time data '7 2002' does not match format '%B %d %Y'
# Error processing date: April 11 - 14, 2002, Error: time data '14 2002' does not match format '%B %d %Y'
# Error processing date: April 18 - 21, 2002, Error: time data '21 2002' does not match format '%B %d %Y'
# Error processing date: April 25 - 28, 2002, Error: time data '28 2002' does not match format '%B %d %Y'
# Error processing date: May 2 - 5, 2002, Error: time data '5 2002' does not match format '%B %d %Y'
# Error processing date: May 9 - 12, 2002, Error: time data '12 2002' does not match format '%B %d %Y'
# Error processing date: May 16 - 19, 2002, Error: time data '19 2002' does not match format '%B %d %Y'
# Error processing date: May 23 - 26, 2002, Error: time data '26 2002' does not match format '%B %d %Y'
# Error processing date: June 6 - 9, 2002, Error: time data '9 2002' does not match format '%B %d %Y'
# Error processing date: June 13 - 16, 2002, Error: time data '16 2002' does not match format '%B %d %Y'
# Error processing date: June 20 - 23, 2002, Error: time data '23 2002' does not match format '%B %d %Y'
# Error processing date: June 27 - 30, 2002, Error: time data '30 2002' does not match format '%B %d %Y'
# Error processing date: July 4 - 7, 2002, Error: time data '7 2002' does not match format '%B %d %Y'
# Error processing date: July 11 - 14, 2002, Error: time data '14 2002' does not match format '%B %d %Y'
# Error processing date: July 18 - 21, 2002, Error: time data '21 2002' does not match format '%B %d %Y'
# Error processing date: July 18 - 21, 2002, Error: time data '21 2002' does not match format '%B %d %Y'
# Error processing date: July 25 - 28, 2002, Error: time data '28 2002' does not match format '%B %d %Y'
# Error processing date: August 1 - 4, 2002, Error: time data '4 2002' does not match format '%B %d %Y'
# Error processing date: August 8 - 11, 2002, Error: time data '11 2002' does not match format '%B %d %Y'
# Error processing date: August 14 - 17, 2003, Error: time data '17 2003' does not match format '%B %d %Y'
# Error processing date: August 21 - 24, 2003, Error: time data '24 2003' does not match format '%B %d %Y'
# Error processing date: August 21 - 24, 2003, Error: time data '24 2003' does not match format '%B %d %Y'
# Error processing date: September 4 - 7, 2003, Error: time data '7 2003' does not match format '%B %d %Y'
# Error processing date: September 11 - 14, 2003, Error: time data '14 2003' does not match format '%B %d %Y'
# Error processing date: September 18 - 21, 2003, Error: time data '21 2003' does not match format '%B %d %Y'
# Error processing date: September 25 - 28, 2003, Error: time data '28 2003' does not match format '%B %d %Y'
# Error processing date: October 2 - 5, 2003, Error: time data '5 2003' does not match format '%B %d %Y'
# Error processing date: October 2 - 5, 2003, Error: time data '5 2003' does not match format '%B %d %Y'
# Error processing date: October 8 - 12, 2003, Error: time data '12 2003' does not match format '%B %d %Y'
# Error processing date: October 16 - 19, 2003, Error: time data '19 2003' does not match format '%B %d %Y'
# Error processing date: October 23 - 26, 2003, Error: time data '26 2003' does not match format '%B %d %Y'
# Error processing date: Oct 30 - November 2, 2003, Error: time data 'Oct 30 2003' does not match format '%B %d %Y'
# Error processing date: November 6 - 9, 2003, Error: time data '9 2003' does not match format '%B %d %Y'
# Error processing date: Feb 27 - March 2, 2003, Error: time data 'Feb 27 2003' does not match format '%B %d %Y'
# Error processing date: January 9 - 12, 2003, Error: time data '12 2003' does not match format '%B %d %Y'
# Error processing date: January 16 - 19, 2003, Error: time data '19 2003' does not match format '%B %d %Y'
# Error processing date: January 23 - 26, 2003, Error: time data '26 2003' does not match format '%B %d %Y'
# Error processing date: Jan 29 - February 2, 2003, Error: time data 'Jan 29 2003' does not match format '%B %d %Y'
# Error processing date: February 6 - 9, 2003, Error: time data '9 2003' does not match format '%B %d %Y'
# Error processing date: February 13 - 16, 2003, Error: time data '16 2003' does not match format '%B %d %Y'
# Error processing date: February 20 - 23, 2003, Error: time data '23 2003' does not match format '%B %d %Y'
# Error processing date: Feb 27 - March 2, 2003, Error: time data 'Feb 27 2003' does not match format '%B %d %Y'
# Error processing date: March 6 - 9, 2003, Error: time data '9 2003' does not match format '%B %d %Y'
# Error processing date: March 13 - 16, 2003, Error: time data '16 2003' does not match format '%B %d %Y'
# Error processing date: March 20 - 23, 2003, Error: time data '23 2003' does not match format '%B %d %Y'
# Error processing date: March 27 - 30, 2003, Error: time data '30 2003' does not match format '%B %d %Y'
# Error processing date: April 3 - 6, 2003, Error: time data '6 2003' does not match format '%B %d %Y'
# Error processing date: April 10 - 13, 2003, Error: time data '13 2003' does not match format '%B %d %Y'
# Error processing date: April 17 - 20, 2003, Error: time data '20 2003' does not match format '%B %d %Y'
# Error processing date: April 24 - 27, 2003, Error: time data '27 2003' does not match format '%B %d %Y'
# Error processing date: May 1 - 4, 2003, Error: time data '4 2003' does not match format '%B %d %Y'
# Error processing date: May 8 - 11, 2003, Error: time data '11 2003' does not match format '%B %d %Y'
# Error processing date: May 15 - 18, 2003, Error: time data '18 2003' does not match format '%B %d %Y'
# Error processing date: May 22 - 25, 2003, Error: time data '25 2003' does not match format '%B %d %Y'
# Error processing date: June 5 - 8, 2003, Error: time data '8 2003' does not match format '%B %d %Y'
# Error processing date: June 12 - 15, 2003, Error: time data '15 2003' does not match format '%B %d %Y'
# Error processing date: June 19 - 22, 2003, Error: time data '22 2003' does not match format '%B %d %Y'
# Error processing date: June 26 - 29, 2003, Error: time data '29 2003' does not match format '%B %d %Y'
# Error processing date: July 3 - 6, 2003, Error: time data '6 2003' does not match format '%B %d %Y'
# Error processing date: July 10 - 13, 2003, Error: time data '13 2003' does not match format '%B %d %Y'
# Error processing date: Aug 29 - September 1, 2003, Error: time data 'Aug 29 2003' does not match format '%B %d %Y'
# Error processing date: July 17 - 20, 2003, Error: time data '20 2003' does not match format '%B %d %Y'
# Error processing date: July 17 - 20, 2003, Error: time data '20 2003' does not match format '%B %d %Y'
# Error processing date: July 24 - 27, 2003, Error: time data '27 2003' does not match format '%B %d %Y'
# Error processing date: Jul 31 - August 3, 2003, Error: time data 'Jul 31 2003' does not match format '%B %d %Y'
# Error processing date: August 7 - 10, 2003, Error: time data '10 2003' does not match format '%B %d %Y'
# Error processing date: January 8 - 11, 2004, Error: time data '11 2004' does not match format '%B %d %Y'
# Error processing date: February 26 - 29, 2004, Error: time data '29 2004' does not match format '%B %d %Y'
# Error processing date: January 21 - 25, 2004, Error: time data '25 2004' does not match format '%B %d %Y'
# Error processing date: Jan 29 - February 1, 2004, Error: time data 'Jan 29 2004' does not match format '%B %d %Y'
# Error processing date: February 5 - 8, 2004, Error: time data '8 2004' does not match format '%B %d %Y'
# Error processing date: February 12 - 15, 2004, Error: time data '15 2004' does not match format '%B %d %Y'
# Error processing date: January 15 - 18, 2004, Error: time data '18 2004' does not match format '%B %d %Y'
# Error processing date: February 19 - 22, 2004, Error: time data '22 2004' does not match format '%B %d %Y'
# Error processing date: March 4 - 7, 2004, Error: time data '7 2004' does not match format '%B %d %Y'
# Error processing date: March 11 - 14, 2004, Error: time data '14 2004' does not match format '%B %d %Y'
# Error processing date: March 18 - 21, 2004, Error: time data '21 2004' does not match format '%B %d %Y'
# Error processing date: Apr 29 - May 2, 2004, Error: time data 'Apr 29 2004' does not match format '%B %d %Y'
# Error processing date: March 25 - 28, 2004, Error: time data '28 2004' does not match format '%B %d %Y'
# Error processing date: April 1 - 4, 2004, Error: time data '4 2004' does not match format '%B %d %Y'
# Error processing date: April 8 - 11, 2004, Error: time data '11 2004' does not match format '%B %d %Y'
# Error processing date: April 15 - 18, 2004, Error: time data '18 2004' does not match format '%B %d %Y'
# Error processing date: October 14 - 17, 2004, Error: time data '17 2004' does not match format '%B %d %Y'
# Error processing date: April 22 - 25, 2004, Error: time data '25 2004' does not match format '%B %d %Y'
# Error processing date: May 13 - 16, 2004, Error: time data '16 2004' does not match format '%B %d %Y'
# Error processing date: May 20 - 23, 2004, Error: time data '23 2004' does not match format '%B %d %Y'
# Error processing date: June 24 - 27, 2004, Error: time data '27 2004' does not match format '%B %d %Y'
# Error processing date: June 3 - 6, 2004, Error: time data '6 2004' does not match format '%B %d %Y'
# Error processing date: June 10 - 13, 2004, Error: time data '13 2004' does not match format '%B %d %Y'
# Error processing date: June 17 - 20, 2004, Error: time data '20 2004' does not match format '%B %d %Y'
# Error processing date: May 27 - 30, 2004, Error: time data '30 2004' does not match format '%B %d %Y'
# Error processing date: August 26 - 29, 2004, Error: time data '29 2004' does not match format '%B %d %Y'
# Error processing date: July 1 - 4, 2004, Error: time data '4 2004' does not match format '%B %d %Y'
# Error processing date: July 15 - 18, 2004, Error: time data '18 2004' does not match format '%B %d %Y'
# Error processing date: Sep 30 - October 3, 2004, Error: time data 'Sep 30 2004' does not match format '%B %d %Y'
# Error processing date: Jul 29 - August 1, 2004, Error: time data 'Jul 29 2004' does not match format '%B %d %Y'
# Error processing date: August 12 - 15, 2004, Error: time data '15 2004' does not match format '%B %d %Y'
# Error processing date: August 5 - 8, 2004, Error: time data '8 2004' does not match format '%B %d %Y'
# Error processing date: August 19 - 22, 2004, Error: time data '22 2004' does not match format '%B %d %Y'
# Error processing date: July 22 - 25, 2004, Error: time data '25 2004' does not match format '%B %d %Y'
# Error processing date: September 9 - 12, 2004, Error: time data '12 2004' does not match format '%B %d %Y'
# Error processing date: July 8 - 11, 2004, Error: time data '11 2004' does not match format '%B %d %Y'
# Error processing date: July 15 - 18, 2004, Error: time data '18 2004' does not match format '%B %d %Y'
# Error processing date: September 16 - 19, 2004, Error: time data '19 2004' does not match format '%B %d %Y'
# Error processing date: October 21 - 24, 2004, Error: time data '24 2004' does not match format '%B %d %Y'
# Error processing date: November 4 - 7, 2004, Error: time data '7 2004' does not match format '%B %d %Y'
# Error processing date: September 23 - 26, 2004, Error: time data '26 2004' does not match format '%B %d %Y'
# Error processing date: October 28 - 31, 2004, Error: time data '31 2004' does not match format '%B %d %Y'
# Error processing date: February 25 - 29, 2004, Error: time data '29 2004' does not match format '%B %d %Y'
# Error processing date: August 19 - 22, 2004, Error: time data '22 2004' does not match format '%B %d %Y'
# Error processing date: Sep 30 - October 3, 2004, Error: time data 'Sep 30 2004' does not match format '%B %d %Y'
# Error processing date: May 6 - 9, 2004, Error: time data '9 2004' does not match format '%B %d %Y'
# Error processing date: September 3 - 6, 2004, Error: time data '6 2004' does not match format '%B %d %Y'
# Error processing date: October 7 - 10, 2004, Error: time data '10 2004' does not match format '%B %d %Y'
# Error processing date: September 17 - 19, 2004, Error: time data '19 2004' does not match format '%B %d %Y'
# Error processing date: January 6 - 9, 2005, Error: time data '9 2005' does not match format '%B %d %Y'
# Error processing date: February 24 - 27, 2005, Error: time data '27 2005' does not match format '%B %d %Y'
# Error processing date: January 26 - 30, 2005, Error: time data '30 2005' does not match format '%B %d %Y'
# Error processing date: February 3 - 6, 2005, Error: time data '6 2005' does not match format '%B %d %Y'
# Error processing date: February 10 - 13, 2005, Error: time data '13 2005' does not match format '%B %d %Y'
# Error processing date: January 20 - 23, 2005, Error: time data '23 2005' does not match format '%B %d %Y'
# Error processing date: January 13 - 16, 2005, Error: time data '16 2005' does not match format '%B %d %Y'
# Error processing date: February 17 - 20, 2005, Error: time data '20 2005' does not match format '%B %d %Y'
# Error processing date: March 3 - 6, 2005, Error: time data '6 2005' does not match format '%B %d %Y'
# Error processing date: March 10 - 13, 2005, Error: time data '13 2005' does not match format '%B %d %Y'
# Error processing date: March 17 - 20, 2005, Error: time data '20 2005' does not match format '%B %d %Y'
# Error processing date: Apr 28 - May 1, 2005, Error: time data 'Apr 28 2005' does not match format '%B %d %Y'
# Error processing date: March 24 - 27, 2005, Error: time data '27 2005' does not match format '%B %d %Y'
# Error processing date: Mar 31 - April 3, 2005, Error: time data 'Mar 31 2005' does not match format '%B %d %Y'
# Error processing date: April 7 - 10, 2005, Error: time data '10 2005' does not match format '%B %d %Y'
# Error processing date: April 14 - 17, 2005, Error: time data '17 2005' does not match format '%B %d %Y'
# Error processing date: Sep 29 - October 2, 2005, Error: time data 'Sep 29 2005' does not match format '%B %d %Y'
# Error processing date: April 21 - 24, 2005, Error: time data '24 2005' does not match format '%B %d %Y'
# Error processing date: May 12 - 15, 2005, Error: time data '15 2005' does not match format '%B %d %Y'
# Error processing date: May 19 - 22, 2005, Error: time data '22 2005' does not match format '%B %d %Y'
# Error processing date: June 9 - 12, 2005, Error: time data '12 2005' does not match format '%B %d %Y'
# Error processing date: June 2 - 5, 2005, Error: time data '5 2005' does not match format '%B %d %Y'
# Error processing date: June 23 - 26, 2005, Error: time data '26 2005' does not match format '%B %d %Y'
# Error processing date: June 16 - 19, 2005, Error: time data '19 2005' does not match format '%B %d %Y'
# Error processing date: May 26 - 29, 2005, Error: time data '29 2005' does not match format '%B %d %Y'
# Error processing date: August 25 - 28, 2005, Error: time data '28 2005' does not match format '%B %d %Y'
# Error processing date: Jun 30 - July 3, 2005, Error: time data 'Jun 30 2005' does not match format '%B %d %Y'
# Error processing date: July 14 - 17, 2005, Error: time data '17 2005' does not match format '%B %d %Y'
# Error processing date: November 3 - 6, 2005, Error: time data '6 2005' does not match format '%B %d %Y'
# Error processing date: July 28 - 31, 2005, Error: time data '31 2005' does not match format '%B %d %Y'
# Error processing date: August 11 - 14, 2005, Error: time data '14 2005' does not match format '%B %d %Y'
# Error processing date: August 4 - 7, 2005, Error: time data '7 2005' does not match format '%B %d %Y'
# Error processing date: August 18 - 21, 2005, Error: time data '21 2005' does not match format '%B %d %Y'
# Error processing date: July 21 - 24, 2005, Error: time data '24 2005' does not match format '%B %d %Y'
# Error processing date: September 8 - 11, 2005, Error: time data '11 2005' does not match format '%B %d %Y'
# Error processing date: July 7 - 10, 2005, Error: time data '10 2005' does not match format '%B %d %Y'
# Error processing date: September 22 - 25, 2005, Error: time data '25 2005' does not match format '%B %d %Y'
# Error processing date: July 14 - 17, 2005, Error: time data '17 2005' does not match format '%B %d %Y'
# Error processing date: October 13 - 16, 2005, Error: time data '16 2005' does not match format '%B %d %Y'
# Error processing date: September 22 - 25, 2005, Error: time data '25 2005' does not match format '%B %d %Y'
# Error processing date: October 20 - 23, 2005, Error: time data '23 2005' does not match format '%B %d %Y'
# Error processing date: November 3 - 6, 2005, Error: time data '6 2005' does not match format '%B %d %Y'
# Error processing date: September 15 - 18, 2005, Error: time data '18 2005' does not match format '%B %d %Y'
# Error processing date: October 27 - 30, 2005, Error: time data '30 2005' does not match format '%B %d %Y'
# Error processing date: February 23 - 27, 2005, Error: time data '27 2005' does not match format '%B %d %Y'
# Error processing date: August 18 - 21, 2005, Error: time data '21 2005' does not match format '%B %d %Y'
# Error processing date: October 6 - 9, 2005, Error: time data '9 2005' does not match format '%B %d %Y'
# Error processing date: May 5 - 8, 2005, Error: time data '8 2005' does not match format '%B %d %Y'
# Error processing date: September 2 - 5, 2005, Error: time data '5 2005' does not match format '%B %d %Y'
# Error processing date: November 18 - 21, 2004, Error: time data '21 2004' does not match format '%B %d %Y'
# Error processing date: January 5 - 8, 2006, Error: time data '8 2006' does not match format '%B %d %Y'
# Error processing date: February 23 - 26, 2006, Error: time data '26 2006' does not match format '%B %d %Y'
# Error processing date: January 18 - 22, 2006, Error: time data '22 2006' does not match format '%B %d %Y'
# Error processing date: February 2 - 5, 2006, Error: time data '5 2006' does not match format '%B %d %Y'
# Error processing date: February 9 - 12, 2006, Error: time data '12 2006' does not match format '%B %d %Y'
# Error processing date: January 26 - 29, 2006, Error: time data '29 2006' does not match format '%B %d %Y'
# Error processing date: January 12 - 15, 2006, Error: time data '15 2006' does not match format '%B %d %Y'
# Error processing date: February 16 - 19, 2006, Error: time data '19 2006' does not match format '%B %d %Y'
# Error processing date: March 2 - 5, 2006, Error: time data '5 2006' does not match format '%B %d %Y'
# Error processing date: March 9 - 12, 2006, Error: time data '12 2006' does not match format '%B %d %Y'
# Error processing date: March 16 - 19, 2006, Error: time data '19 2006' does not match format '%B %d %Y'
# Error processing date: March 23 - 26, 2006, Error: time data '26 2006' does not match format '%B %d %Y'
# Error processing date: Mar 30 - April 2, 2006, Error: time data 'Mar 30 2006' does not match format '%B %d %Y'
# Error processing date: April 6 - 9, 2006, Error: time data '9 2006' does not match format '%B %d %Y'
# Error processing date: April 13 - 16, 2006, Error: time data '16 2006' does not match format '%B %d %Y'
# Error processing date: April 20 - 23, 2006, Error: time data '23 2006' does not match format '%B %d %Y'
# Error processing date: May 11 - 14, 2006, Error: time data '14 2006' does not match format '%B %d %Y'
# Error processing date: May 18 - 21, 2006, Error: time data '21 2006' does not match format '%B %d %Y'
# Error processing date: June 22 - 25, 2006, Error: time data '25 2006' does not match format '%B %d %Y'
# Error processing date: June 1 - 4, 2006, Error: time data '4 2006' does not match format '%B %d %Y'
# Error processing date: June 8 - 11, 2006, Error: time data '11 2006' does not match format '%B %d %Y'
# Error processing date: June 15 - 18, 2006, Error: time data '18 2006' does not match format '%B %d %Y'
# Error processing date: May 25 - 28, 2006, Error: time data '28 2006' does not match format '%B %d %Y'
# Error processing date: Jun 29 - July 2, 2006, Error: time data 'Jun 29 2006' does not match format '%B %d %Y'
# Error processing date: July 6 - 9, 2006, Error: time data '9 2006' does not match format '%B %d %Y'
# Error processing date: August 3 - 6, 2006, Error: time data '6 2006' does not match format '%B %d %Y'
# Error processing date: August 17 - 20, 2006, Error: time data '20 2006' does not match format '%B %d %Y'
# Error processing date: August 10 - 13, 2006, Error: time data '13 2006' does not match format '%B %d %Y'
# Error processing date: July 27 - 30, 2006, Error: time data '30 2006' does not match format '%B %d %Y'
# Error processing date: July 13 - 16, 2006, Error: time data '16 2006' does not match format '%B %d %Y'
# Error processing date: July 20 - 23, 2006, Error: time data '23 2006' does not match format '%B %d %Y'
# Error processing date: February 22 - 26, 2006, Error: time data '26 2006' does not match format '%B %d %Y'
# Error processing date: August 24 - 27, 2006, Error: time data '27 2006' does not match format '%B %d %Y'
# Error processing date: May 4 - 7, 2006, Error: time data '7 2006' does not match format '%B %d %Y'
# Error processing date: September 1 - 4, 2006, Error: time data '4 2006' does not match format '%B %d %Y'
# Error processing date: October 5 - 8, 2006, Error: time data '8 2006' does not match format '%B %d %Y'
# Error processing date: Sep 28 - October 1, 2006, Error: time data 'Sep 28 2006' does not match format '%B %d %Y'
# Error processing date: October 12 - 15, 2006, Error: time data '15 2006' does not match format '%B %d %Y'
# Error processing date: September 21 - 24, 2006, Error: time data '24 2006' does not match format '%B %d %Y'
# Error processing date: October 19 - 22, 2006, Error: time data '22 2006' does not match format '%B %d %Y'
# Error processing date: November 2 - 5, 2006, Error: time data '5 2006' does not match format '%B %d %Y'
# Error processing date: September 14 - 17, 2006, Error: time data '17 2006' does not match format '%B %d %Y'
# Error processing date: October 26 - 29, 2006, Error: time data '29 2006' does not match format '%B %d %Y'
# Error processing date: September 22 - 24, 2006, Error: time data '24 2006' does not match format '%B %d %Y'
# Error processing date: Sep 28 - October 1, 2006, Error: time data 'Sep 28 2006' does not match format '%B %d %Y'
# Error processing date: April 27 - 30, 2006, Error: time data '30 2006' does not match format '%B %d %Y'
# Error processing date: July 20 - 23, 2006, Error: time data '23 2006' does not match format '%B %d %Y'
# Error processing date: August 24 - 27, 2006, Error: time data '27 2006' does not match format '%B %d %Y'
# Error processing date: January 4 - 7, 2007, Error: time data '7 2007' does not match format '%B %d %Y'
# Error processing date: January 17 - 21, 2007, Error: time data '21 2007' does not match format '%B %d %Y'
# Error processing date: February 1 - 4, 2007, Error: time data '4 2007' does not match format '%B %d %Y'
# Error processing date: February 8 - 11, 2007, Error: time data '11 2007' does not match format '%B %d %Y'
# Error processing date: January 25 - 28, 2007, Error: time data '28 2007' does not match format '%B %d %Y'
# Error processing date: January 11 - 14, 2007, Error: time data '14 2007' does not match format '%B %d %Y'
# Error processing date: February 15 - 18, 2007, Error: time data '18 2007' does not match format '%B %d %Y'
# Error processing date: March 1 - 4, 2007, Error: time data '4 2007' does not match format '%B %d %Y'
# Error processing date: March 15 - 18, 2007, Error: time data '18 2007' does not match format '%B %d %Y'
# Error processing date: April 19 - 22, 2007, Error: time data '22 2007' does not match format '%B %d %Y'
# Error processing date: May 10 - 13, 2007, Error: time data '13 2007' does not match format '%B %d %Y'
# Error processing date: May 17 - 20, 2007, Error: time data '20 2007' does not match format '%B %d %Y'
# Error processing date: April 5 - 8, 2007, Error: time data '8 2007' does not match format '%B %d %Y'
# Error processing date: April 12 - 15, 2007, Error: time data '15 2007' does not match format '%B %d %Y'
# Error processing date: Mar 29 - April 1, 2007, Error: time data 'Mar 29 2007' does not match format '%B %d %Y'
# Error processing date: April 26 - 29, 2007, Error: time data '29 2007' does not match format '%B %d %Y'
# Error processing date: May 24 - 27, 2007, Error: time data '27 2007' does not match format '%B %d %Y'
# Error processing date: August 23 - 26, 2007, Error: time data '26 2007' does not match format '%B %d %Y'
# Error processing date: June 14 - 17, 2007, Error: time data '17 2007' does not match format '%B %d %Y'
# Error processing date: June 7 - 10, 2007, Error: time data '10 2007' does not match format '%B %d %Y'
# Error processing date: June 21 - 24, 2007, Error: time data '24 2007' does not match format '%B %d %Y'
# Error processing date: September 6 - 9, 2007, Error: time data '9 2007' does not match format '%B %d %Y'
# Error processing date: July 19 - 22, 2007, Error: time data '22 2007' does not match format '%B %d %Y'
# Error processing date: Jun 28 - July 1, 2007, Error: time data 'Jun 28 2007' does not match format '%B %d %Y'
# Error processing date: August 9 - 12, 2007, Error: time data '12 2007' does not match format '%B %d %Y'
# Error processing date: August 2 - 5, 2007, Error: time data '5 2007' does not match format '%B %d %Y'
# Error processing date: July 19 - 22, 2007, Error: time data '22 2007' does not match format '%B %d %Y'
# Error processing date: July 26 - 29, 2007, Error: time data '29 2007' does not match format '%B %d %Y'
# Error processing date: July 12 - 15, 2007, Error: time data '15 2007' does not match format '%B %d %Y'
# Error processing date: October 11 - 14, 2007, Error: time data '14 2007' does not match format '%B %d %Y'
# Error processing date: October 4 - 7, 2007, Error: time data '7 2007' does not match format '%B %d %Y'
# Error processing date: September 13 - 16, 2007, Error: time data '16 2007' does not match format '%B %d %Y'
# Error processing date: February 21 - 25, 2007, Error: time data '25 2007' does not match format '%B %d %Y'
# Error processing date: August 2 - 5, 2007, Error: time data '5 2007' does not match format '%B %d %Y'
# Error processing date: May 3 - 6, 2007, Error: time data '6 2007' does not match format '%B %d %Y'
# Error processing date: Aug 31 - September 3, 2007, Error: time data 'Aug 31 2007' does not match format '%B %d %Y'
# Error processing date: February 22 - 25, 2007, Error: time data '25 2007' does not match format '%B %d %Y'
# Error processing date: September 20 - 23, 2007, Error: time data '23 2007' does not match format '%B %d %Y'
# Error processing date: October 18 - 21, 2007, Error: time data '21 2007' does not match format '%B %d %Y'
# Error processing date: August 16 - 19, 2007, Error: time data '19 2007' does not match format '%B %d %Y'
# Error processing date: September 27 - 30, 2007, Error: time data '30 2007' does not match format '%B %d %Y'
# Error processing date: September 27 - 30, 2007, Error: time data '30 2007' does not match format '%B %d %Y'
# Error processing date: November 1 - 4, 2007, Error: time data '4 2007' does not match format '%B %d %Y'
# Error processing date: March 8 - 11, 2007, Error: time data '11 2007' does not match format '%B %d %Y'
# Error processing date: March 22 - 25, 2007, Error: time data '25 2007' does not match format '%B %d %Y'
# Error processing date: December 7 - 10, 2006, Error: time data '10 2006' does not match format '%B %d %Y'
# Error processing date: July 5 - 8, 2007, Error: time data '8 2007' does not match format '%B %d %Y'
# Error processing date: January 19 - 21, 2007, Error: time data '21 2007' does not match format '%B %d %Y'
# Error processing date: January 25 - 28, 2007, Error: time data '28 2007' does not match format '%B %d %Y'
# Error processing date: January 26 - 28, 2007, Error: time data '28 2007' does not match format '%B %d %Y'
# Error processing date: February 9 - 11, 2007, Error: time data '11 2007' does not match format '%B %d %Y'
# Error processing date: February 15 - 18, 2007, Error: time data '18 2007' does not match format '%B %d %Y'
# Error processing date: February 16 - 18, 2007, Error: time data '18 2007' does not match format '%B %d %Y'
# Error processing date: February 22 - 25, 2007, Error: time data '25 2007' does not match format '%B %d %Y'
# Error processing date: February 23 - 25, 2007, Error: time data '25 2007' does not match format '%B %d %Y'
# Error processing date: March 9 - 11, 2007, Error: time data '11 2007' does not match format '%B %d %Y'
# Error processing date: March 16 - 18, 2007, Error: time data '18 2007' does not match format '%B %d %Y'
# Error processing date: March 22 - 25, 2007, Error: time data '25 2007' does not match format '%B %d %Y'
# Error processing date: Mar 29 - April 1, 2007, Error: time data 'Mar 29 2007' does not match format '%B %d %Y'
# Error processing date: Mar 30 - April 1, 2007, Error: time data 'Mar 30 2007' does not match format '%B %d %Y'
# Error processing date: April 12 - 15, 2007, Error: time data '15 2007' does not match format '%B %d %Y'
# Error processing date: April 19 - 22, 2007, Error: time data '22 2007' does not match format '%B %d %Y'
# Error processing date: April 20 - 22, 2007, Error: time data '22 2007' does not match format '%B %d %Y'
# Error processing date: April 26 - 29, 2007, Error: time data '29 2007' does not match format '%B %d %Y'
# Error processing date: May 3 - 6, 2007, Error: time data '6 2007' does not match format '%B %d %Y'
# Error processing date: May 4 - 7, 2007, Error: time data '7 2007' does not match format '%B %d %Y'
# Error processing date: October 18 - 21, 2007, Error: time data '21 2007' does not match format '%B %d %Y'
# Error processing date: May 17 - 20, 2007, Error: time data '20 2007' does not match format '%B %d %Y'
# Error processing date: May 18 - 20, 2007, Error: time data '20 2007' does not match format '%B %d %Y'
# Error processing date: May 24 - 27, 2007, Error: time data '27 2007' does not match format '%B %d %Y'
# Error processing date: May 24 - 27, 2007, Error: time data '27 2007' does not match format '%B %d %Y'
# Error processing date: June 1 - 3, 2007, Error: time data '3 2007' does not match format '%B %d %Y'
# Error processing date: June 7 - 10, 2007, Error: time data '10 2007' does not match format '%B %d %Y'
# Error processing date: June 8 - 10, 2007, Error: time data '10 2007' does not match format '%B %d %Y'
# Error processing date: June 21 - 24, 2007, Error: time data '24 2007' does not match format '%B %d %Y'
# Error processing date: June 22 - 24, 2007, Error: time data '24 2007' does not match format '%B %d %Y'
# Error processing date: Jun 28 - July 1, 2007, Error: time data 'Jun 28 2007' does not match format '%B %d %Y'
# Error processing date: Jun 29 - July 1, 2007, Error: time data 'Jun 29 2007' does not match format '%B %d %Y'
# Error processing date: July 5 - 8, 2007, Error: time data '8 2007' does not match format '%B %d %Y'
# Error processing date: July 5 - 8, 2007, Error: time data '8 2007' does not match format '%B %d %Y'
# Error processing date: June 14 - 17, 2007, Error: time data '17 2007' does not match format '%B %d %Y'
# Error processing date: July 13 - 15, 2007, Error: time data '15 2007' does not match format '%B %d %Y'
# Error processing date: July 19 - 22, 2007, Error: time data '22 2007' does not match format '%B %d %Y'
# Error processing date: July 26 - 29, 2007, Error: time data '29 2007' does not match format '%B %d %Y'
# Error processing date: July 26 - 29, 2007, Error: time data '29 2007' does not match format '%B %d %Y'
# Error processing date: August 2 - 5, 2007, Error: time data '5 2007' does not match format '%B %d %Y'
# Error processing date: August 3 - 5, 2007, Error: time data '5 2007' does not match format '%B %d %Y'
# Error processing date: August 9 - 12, 2007, Error: time data '12 2007' does not match format '%B %d %Y'
# Error processing date: August 16 - 19, 2007, Error: time data '19 2007' does not match format '%B %d %Y'
# Error processing date: August 16 - 19, 2007, Error: time data '19 2007' does not match format '%B %d %Y'
# Error processing date: August 23 - 26, 2007, Error: time data '26 2007' does not match format '%B %d %Y'
# Error processing date: Aug 31 - September 2, 2007, Error: time data 'Aug 31 2007' does not match format '%B %d %Y'
# Error processing date: September 6 - 9, 2007, Error: time data '9 2007' does not match format '%B %d %Y'
# Error processing date: September 13 - 16, 2007, Error: time data '16 2007' does not match format '%B %d %Y'
# Error processing date: September 14 - 16, 2007, Error: time data '16 2007' does not match format '%B %d %Y'
# Error processing date: September 20 - 23, 2007, Error: time data '23 2007' does not match format '%B %d %Y'
# Error processing date: September 21 - 23, 2007, Error: time data '23 2007' does not match format '%B %d %Y'
# Error processing date: October 4 - 7, 2007, Error: time data '7 2007' does not match format '%B %d %Y'
# Error processing date: October 4 - 7, 2007, Error: time data '7 2007' does not match format '%B %d %Y'
# Error processing date: October 11 - 14, 2007, Error: time data '14 2007' does not match format '%B %d %Y'
# Error processing date: October 12 - 14, 2007, Error: time data '14 2007' does not match format '%B %d %Y'
# Error processing date: October 19 - 21, 2007, Error: time data '21 2007' does not match format '%B %d %Y'
# Error processing date: October 25 - 28, 2007, Error: time data '28 2007' does not match format '%B %d %Y'
# Error processing date: October 25 - 28, 2007, Error: time data '28 2007' does not match format '%B %d %Y'
# Error processing date: November 1 - 4, 2007, Error: time data '4 2007' does not match format '%B %d %Y'
# Error processing date: July 12 - 15, 2007, Error: time data '15 2007' does not match format '%B %d %Y'
# Error processing date: October 25 - 28, 2007, Error: time data '28 2007' does not match format '%B %d %Y'
# Error processing date: July 17 - 20, 2008, Error: time data '20 2008' does not match format '%B %d %Y'
# Error processing date: February 20 - 24, 2008, Error: time data '24 2008' does not match format '%B %d %Y'
# Error processing date: January 3 - 6, 2008, Error: time data '6 2008' does not match format '%B %d %Y'
# Error processing date: January 16 - 20, 2008, Error: time data '20 2008' does not match format '%B %d %Y'
# Error processing date: Jan 31 - February 3, 2008, Error: time data 'Jan 31 2008' does not match format '%B %d %Y'
# Error processing date: January 24 - 27, 2008, Error: time data '27 2008' does not match format '%B %d %Y'
# Error processing date: January 10 - 13, 2008, Error: time data '13 2008' does not match format '%B %d %Y'
# Error processing date: February 14 - 17, 2008, Error: time data '17 2008' does not match format '%B %d %Y'
# Error processing date: Feb 28 - March 2, 2008, Error: time data 'Feb 28 2008' does not match format '%B %d %Y'
# Error processing date: March 13 - 16, 2008, Error: time data '16 2008' does not match format '%B %d %Y'
# Error processing date: March 27 - 30, 2008, Error: time data '30 2008' does not match format '%B %d %Y'
# Error processing date: May 8 - 11, 2008, Error: time data '11 2008' does not match format '%B %d %Y'
# ...
# Error processing date: June 23 - 26, 2022, Error: time data '26 2022' does not match format '%B %d %Y'
# Error processing date: June 16 - 19, 2022, Error: time data '19 2022' does not match format '%B %d %Y'
# Error processing date: June 9 - 12, 2022, Error: time data '12 2022' does not match format '%B %d %Y'
# Error processing date: June 2 - 5, 2022, Error: time data '5 2022' does not match format '%B %d %Y'
# Error processing date: May 26 - 29, 2022, Error: time data '29 2022' does not match format '%B %d %Y'
# Error processing date: May 19 - 22, 2022, Error: time data '22 2022' does not match format '%B %d %Y'
# Error processing date: May 12 - 15, 2022, Error: time data '15 2022' does not match format '%B %d %Y'
# Error processing date: May 5 - 8, 2022, Error: time data '8 2022' does not match format '%B %d %Y'
# Error processing date: Apr 28 - May 1, 2022, Error: time data 'Apr 28 2022' does not match format '%B %d %Y'
# Error processing date: April 21 - 24, 2022, Error: time data '24 2022' does not match format '%B %d %Y'
# Error processing date: April 14 - 17, 2022, Error: time data '17 2022' does not match format '%B %d %Y'
# Error processing date: April 7 - 10, 2022, Error: time data '10 2022' does not match format '%B %d %Y'
# Error processing date: January 20 - 23, 2022, Error: time data '23 2022' does not match format '%B %d %Y'
# Error processing date: January 26 - 29, 2022, Error: time data '29 2022' does not match format '%B %d %Y'
# Error processing date: February 3 - 6, 2022, Error: time data '6 2022' does not match format '%B %d %Y'
# Error processing date: February 10 - 13, 2022, Error: time data '13 2022' does not match format '%B %d %Y'
# Error processing date: February 17 - 20, 2022, Error: time data '20 2022' does not match format '%B %d %Y'
# Error processing date: February 24 - 27, 2022, Error: time data '27 2022' does not match format '%B %d %Y'
# Error processing date: March 3 - 6, 2022, Error: time data '6 2022' does not match format '%B %d %Y'
# Error processing date: March 3 - 6, 2022, Error: time data '6 2022' does not match format '%B %d %Y'
# Error processing date: March 10 - 14, 2022, Error: time data '14 2022' does not match format '%B %d %Y'
# Error processing date: March 17 - 20, 2022, Error: time data '20 2022' does not match format '%B %d %Y'
# Error processing date: Mar 31 - April 3, 2022, Error: time data 'Mar 31 2022' does not match format '%B %d %Y'
# Error processing date: August 11 - 14, 2022, Error: time data '14 2022' does not match format '%B %d %Y'
# Error processing date: August 18 - 21, 2022, Error: time data '21 2022' does not match format '%B %d %Y'
# Error processing date: August 25 - 28, 2022, Error: time data '28 2022' does not match format '%B %d %Y'
# Error processing date: September 15 - 18, 2022, Error: time data '18 2022' does not match format '%B %d %Y'
# Error processing date: September 22 - 25, 2022, Error: time data '25 2022' does not match format '%B %d %Y'
# Error processing date: Sep 29 - October 2, 2022, Error: time data 'Sep 29 2022' does not match format '%B %d %Y'
# Error processing date: October 6 - 9, 2022, Error: time data '9 2022' does not match format '%B %d %Y'
# Error processing date: October 13 - 16, 2022, Error: time data '16 2022' does not match format '%B %d %Y'
# Error processing date: October 20 - 23, 2022, Error: time data '23 2022' does not match format '%B %d %Y'
# Error processing date: Mar 30 - April 2, 2023, Error: time data 'Mar 30 2023' does not match format '%B %d %Y'
# Error processing date: October 27 - 30, 2022, Error: time data '30 2022' does not match format '%B %d %Y'
# Error processing date: November 3 - 6, 2022, Error: time data '6 2022' does not match format '%B %d %Y'
# Error processing date: November 10 - 13, 2022, Error: time data '13 2022' does not match format '%B %d %Y'
# Error processing date: November 17 - 20, 2022, Error: time data '20 2022' does not match format '%B %d %Y'
# Error processing date: December 1 - 4, 2022, Error: time data '4 2022' does not match format '%B %d %Y'
# Error processing date: April 6 - 9, 2023, Error: time data '9 2023' does not match format '%B %d %Y'
# Error processing date: April 13 - 16, 2023, Error: time data '16 2023' does not match format '%B %d %Y'
# Error processing date: April 20 - 23, 2023, Error: time data '23 2023' does not match format '%B %d %Y'
# Error processing date: January 5 - 8, 2023, Error: time data '8 2023' does not match format '%B %d %Y'
# Error processing date: January 12 - 15, 2023, Error: time data '15 2023' does not match format '%B %d %Y'
# Error processing date: January 19 - 22, 2023, Error: time data '22 2023' does not match format '%B %d %Y'
# Error processing date: April 27 - 30, 2023, Error: time data '30 2023' does not match format '%B %d %Y'
# Error processing date: January 25 - 28, 2023, Error: time data '28 2023' does not match format '%B %d %Y'
# Error processing date: February 2 - 6, 2023, Error: time data '6 2023' does not match format '%B %d %Y'
# Error processing date: February 9 - 12, 2023, Error: time data '12 2023' does not match format '%B %d %Y'
# Error processing date: May 4 - 7, 2023, Error: time data '7 2023' does not match format '%B %d %Y'
# Error processing date: May 11 - 14, 2023, Error: time data '14 2023' does not match format '%B %d %Y'
# Error processing date: February 16 - 19, 2023, Error: time data '19 2023' does not match format '%B %d %Y'
# Error processing date: February 23 - 26, 2023, Error: time data '26 2023' does not match format '%B %d %Y'
# Error processing date: May 18 - 21, 2023, Error: time data '21 2023' does not match format '%B %d %Y'
# Error processing date: March 2 - 5, 2023, Error: time data '5 2023' does not match format '%B %d %Y'
# Error processing date: March 2 - 5, 2023, Error: time data '5 2023' does not match format '%B %d %Y'
# Error processing date: March 9 - 12, 2023, Error: time data '12 2023' does not match format '%B %d %Y'
# Error processing date: March 16 - 19, 2023, Error: time data '19 2023' does not match format '%B %d %Y'
# Error processing date: March 22 - 26, 2023, Error: time data '26 2023' does not match format '%B %d %Y'
# Error processing date: March 23 - 26, 2023, Error: time data '26 2023' does not match format '%B %d %Y'
# Error processing date: May 25 - 28, 2023, Error: time data '28 2023' does not match format '%B %d %Y'
# Error processing date: June 1 - 4, 2023, Error: time data '4 2023' does not match format '%B %d %Y'
# Error processing date: June 8 - 11, 2023, Error: time data '11 2023' does not match format '%B %d %Y'
# Error processing date: June 15 - 18, 2023, Error: time data '18 2023' does not match format '%B %d %Y'
# Error processing date: June 22 - 25, 2023, Error: time data '25 2023' does not match format '%B %d %Y'
# Error processing date: Jun 29 - July 2, 2023, Error: time data 'Jun 29 2023' does not match format '%B %d %Y'
# Error processing date: July 6 - 9, 2023, Error: time data '9 2023' does not match format '%B %d %Y'
# Error processing date: July 13 - 16, 2023, Error: time data '16 2023' does not match format '%B %d %Y'
# Error processing date: July 13 - 16, 2023, Error: time data '16 2023' does not match format '%B %d %Y'
# Error processing date: July 20 - 23, 2023, Error: time data '23 2023' does not match format '%B %d %Y'
# Error processing date: July 20 - 23, 2023, Error: time data '23 2023' does not match format '%B %d %Y'
# Error processing date: July 27 - 30, 2023, Error: time data '30 2023' does not match format '%B %d %Y'
# Error processing date: August 3 - 6, 2023, Error: time data '6 2023' does not match format '%B %d %Y'
# Error processing date: August 10 - 13, 2023, Error: time data '13 2023' does not match format '%B %d %Y'
# Error processing date: August 17 - 20, 2023, Error: time data '20 2023' does not match format '%B %d %Y'
# Error processing date: August 24 - 27, 2023, Error: time data '27 2023' does not match format '%B %d %Y'
# Error processing date: September 14 - 17, 2023, Error: time data '17 2023' does not match format '%B %d %Y'
# Error processing date: October 5 - 8, 2023, Error: time data '8 2023' does not match format '%B %d %Y'
# Error processing date: October 12 - 15, 2023, Error: time data '15 2023' does not match format '%B %d %Y'
# Error processing date: October 19 - 22, 2023, Error: time data '22 2023' does not match format '%B %d %Y'
# Error processing date: November 2 - 5, 2023, Error: time data '5 2023' does not match format '%B %d %Y'
# Error processing date: November 9 - 12, 2023, Error: time data '12 2023' does not match format '%B %d %Y'
# Error processing date: November 16 - 19, 2023, Error: time data '19 2023' does not match format '%B %d %Y'
# Error processing date: Nov 30 - December 3, 2023, Error: time data 'Nov 30 2023' does not match format '%B %d %Y'
# Error processing date: January 4 - 7, 2024, Error: time data '7 2024' does not match format '%B %d %Y'
# Error processing date: January 11 - 14, 2024, Error: time data '14 2024' does not match format '%B %d %Y'
# Error processing date: January 18 - 21, 2024, Error: time data '21 2024' does not match format '%B %d %Y'
# Error processing date: January 24 - 27, 2024, Error: time data '27 2024' does not match format '%B %d %Y'
# Error processing date: February 1 - 3, 2024, Error: time data '3 2024' does not match format '%B %d %Y'
# Error processing date: February 8 - 11, 2024, Error: time data '11 2024' does not match format '%B %d %Y'
# Error processing date: February 15 - 18, 2024, Error: time data '18 2024' does not match format '%B %d %Y'
# Error processing date: February 22 - 25, 2024, Error: time data '25 2024' does not match format '%B %d %Y'
# Error processing date: Feb 29 - March 3, 2024, Error: time data 'Feb 29 2024' does not match format '%B %d %Y'
# Error processing date: March 7 - 10, 2024, Error: time data '10 2024' does not match format '%B %d %Y'
# Error processing date: March 7 - 10, 2024, Error: time data '10 2024' does not match format '%B %d %Y'
# Error processing date: March 14 - 17, 2024, Error: time data '17 2024' does not match format '%B %d %Y'
# Error processing date: March 21 - 24, 2024, Error: time data '24 2024' does not match format '%B %d %Y'
# Error processing date: March 28 - 31, 2024, Error: time data '31 2024' does not match format '%B %d %Y'
# Error processing date: April 4 - 7, 2024, Error: time data '7 2024' does not match format '%B %d %Y'
# Error processing date: April 11 - 14, 2024, Error: time data '14 2024' does not match format '%B %d %Y'
# Error processing date: April 18 - 22, 2024, Error: time data '22 2024' does not match format '%B %d %Y'
# Error processing date: April 18 - 21, 2024, Error: time data '21 2024' does not match format '%B %d %Y'
# Error processing date: April 25 - 28, 2024, Error: time data '28 2024' does not match format '%B %d %Y'
# Error processing date: May 2 - 5, 2024, Error: time data '5 2024' does not match format '%B %d %Y'
# Error processing date: May 9 - 12, 2024, Error: time data '12 2024' does not match format '%B %d %Y'
# Error processing date: May 9 - 12, 2024, Error: time data '12 2024' does not match format '%B %d %Y'
# Error processing date: May 16 - 19, 2024, Error: time data '19 2024' does not match format '%B %d %Y'
# Error processing date: May 23 - 26, 2024, Error: time data '26 2024' does not match format '%B %d %Y'
# Error processing date: June 6 - 9, 2024, Error: time data '9 2024' does not match format '%B %d %Y'
# Error processing date: June 13 - 16, 2024, Error: time data '16 2024' does not match format '%B %d %Y'
# Error processing date: June 20 - 23, 2024, Error: time data '23 2024' does not match format '%B %d %Y'
# Error processing date: June 27 - 30, 2024, Error: time data '30 2024' does not match format '%B %d %Y'
# Error processing date: July 4 - 7, 2024, Error: time data '7 2024' does not match format '%B %d %Y'
# Error processing date: July 11 - 14, 2024, Error: time data '14 2024' does not match format '%B %d %Y'
# Error processing date: July 18 - 21, 2024, Error: time data '21 2024' does not match format '%B %d %Y'
# Error processing date: July 18 - 21, 2024, Error: time data '21 2024' does not match format '%B %d %Y'
# Error processing date: July 25 - 28, 2024, Error: time data '28 2024' does not match format '%B %d %Y'
# Error processing date: August 8 - 12, 2024, Error: time data '12 2024' does not match format '%B %d %Y'
# Error processing date: August 15 - 18, 2024, Error: time data '18 2024' does not match format '%B %d %Y'
# Error processing date: August 22 - 25, 2024, Error: time data '25 2024' does not match format '%B %d %Y'
# Error processing date: Aug 29 - September 1, 2024, Error: time data 'Aug 29 2024' does not match format '%B %d %Y'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/sj/kb7kr7w572z54pgv0pftb9v00000gn/T/ipykernel_40016/2089954354.py in <module>
#      29         return np.nan, np.nan
#      30
# ---> 31 details_df[['start_date', 'end_date']] = details_df['event_date'].apply(lambda x: pd.Series(extract_start_end_dates(x)))
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py in apply_standard(self)
#    1105             # GH 25959 use pd.array instead of tolist
#    1106             # so extension arrays can be used
# -> 1107             return obj._constructor_expanddim(pd_array(mapped), index=obj.index)
#    1108         else:
#    1109             return obj._constructor(mapped, index=obj.index).__finalize__(
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     692                         # ndarray], Index, Series], Sequence[Any]]"
#     693                         columns = ensure_index(columns)  # type: ignore[arg-type]
# --> 694                     arrays, columns, index = nested_data_to_arrays(
#     695                         # error: Argument 3 to "nested_data_to_arrays" has incompatible
#     696                         # type "Optional[Collection[Any]]"; expected "Optional[Index]"
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/construction.py in nested_data_to_arrays(data, columns, index, dtype)
#     481         columns = ensure_index(data[0]._fields)
#     482
# --> 483     arrays, columns = to_arrays(data, columns, dtype=dtype)
#     484     columns = ensure_index(columns)
#     485
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/construction.py in to_arrays(data, columns, dtype)
#     799         arr, columns = _list_of_dict_to_arrays(data, columns)
#     800     elif isinstance(data[0], ABCSeries):
# --> 801         arr, columns = _list_of_series_to_arrays(data, columns)
#     802     else:
#     803         # last ditch effort
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/construction.py in _list_of_series_to_arrays(data, columns)
#     851     # Sequence[Union[int, float, complex, str, bytes, generic]],
#     852     # Sequence[Sequence[Any]], _SupportsArray]]"
# --> 853     content = np.vstack(aligned_values)  # type: ignore[arg-type]
#     854
#     855     return content, columns
#
# <__array_function__ internals> in vstack(*args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/numpy/core/shape_base.py in vstack(tup)
#     281     if not isinstance(arrs, list):
#     282         arrs = [arrs]
# --> 283     return _nx.concatenate(arrs, 0)
#     284
#     285
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# TypeError: The DTypes <class 'numpy.dtype[datetime64]'> and <class 'numpy.dtype[float64]'> do not have a common DType. For example they cannot be stored in a single array unless the dtype is `object`.
